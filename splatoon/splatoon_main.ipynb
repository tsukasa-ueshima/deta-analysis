# %%
import numpy as np
import pandas as pd
import collections

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

import pprint
from collections import OrderedDict
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelBinarizer
from sklearn import preprocessing

# %%
# トレーニングデータ、テストデータ、サンプルサブミットデータを読み込み
train = pd.read_csv('train_data.csv')
test = pd.read_csv('test_data.csv')

# %%
print(train.shape) # 学習用データ
print(test.shape) # 本番予測用データ
# Out:
# (66125, 32)
# (28340, 31)

# %%
print(train.columns) # トレーニングデータの列名
print('-' * 10) # 区切り線を表示
print(test.columns) # テストデータの列名
# Out:
# Index(['id', 'period', 'game-ver', 'lobby-mode', 'lobby', 'mode', 'stage',
#        'A1-weapon', 'A1-rank', 'A1-level', 'A2-weapon', 'A2-rank', 'A2-level',
#        'A3-weapon', 'A3-rank', 'A3-level', 'A4-weapon', 'A4-rank', 'A4-level',
#        'B1-weapon', 'B1-rank', 'B1-level', 'B2-weapon', 'B2-rank', 'B2-level',
#        'B3-weapon', 'B3-rank', 'B3-level', 'B4-weapon', 'B4-rank', 'B4-level',
#        'y'],
#       dtype='object')
# ----------
# Index(['id', 'period', 'game-ver', 'lobby-mode', 'lobby', 'mode', 'stage',
#        'A1-weapon', 'A1-rank', 'A1-level', 'A2-weapon', 'A2-rank', 'A2-level',
#        'A3-weapon', 'A3-rank', 'A3-level', 'A4-weapon', 'A4-rank', 'A4-level',
#        'B1-weapon', 'B1-rank', 'B1-level', 'B2-weapon', 'B2-rank', 'B2-level',
#        'B3-weapon', 'B3-rank', 'B3-level', 'B4-weapon', 'B4-rank', 'B4-level'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66125 entries, 0 to 66124
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          66125 non-null  int64
#  1   period      66125 non-null  object
#  2   game-ver    66125 non-null  object
#  3   lobby-mode  66125 non-null  object
#  4   lobby       66125 non-null  object
#  5   mode        66125 non-null  object
#  6   stage       66125 non-null  object
#  7   A1-weapon   66125 non-null  object
#  8   A1-rank     51681 non-null  object
#  9   A1-level    66125 non-null  int64
#  10  A2-weapon   66125 non-null  object
#  11  A2-rank     51681 non-null  object
#  12  A2-level    66125 non-null  float64
#  13  A3-weapon   66125 non-null  object
#  14  A3-rank     51681 non-null  object
#  15  A3-level    66125 non-null  float64
#  16  A4-weapon   66074 non-null  object
#  17  A4-rank     51638 non-null  object
#  18  A4-level    66074 non-null  float64
#  19  B1-weapon   66125 non-null  object
#  20  B1-rank     51681 non-null  object
#  21  B1-level    66125 non-null  int64
#  22  B2-weapon   66125 non-null  object
#  23  B2-rank     51681 non-null  object
#  24  B2-level    66125 non-null  float64
#  25  B3-weapon   66124 non-null  object
#  26  B3-rank     51681 non-null  object
#  27  B3-level    66124 non-null  float64
#  28  B4-weapon   66058 non-null  object
#  29  B4-rank     51624 non-null  object
#  30  B4-level    66058 non-null  float64
#  31  y           66125 non-null  int64
# dtypes: float64(6), int64(4), object(22)
# memory usage: 16.1+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28340 entries, 0 to 28339
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          28340 non-null  int64
#  1   period      28340 non-null  object
#  2   game-ver    28340 non-null  object
#  3   lobby-mode  28340 non-null  object
#  4   lobby       28340 non-null  object
#  5   mode        28340 non-null  object
#  6   stage       28340 non-null  object
#  7   A1-weapon   28340 non-null  object
#  8   A1-rank     22068 non-null  object
#  9   A1-level    28340 non-null  int64
#  10  A2-weapon   28340 non-null  object
#  11  A2-rank     22068 non-null  object
#  12  A2-level    28340 non-null  float64
#  13  A3-weapon   28340 non-null  object
#  14  A3-rank     22068 non-null  object
#  15  A3-level    28340 non-null  float64
#  16  A4-weapon   28325 non-null  object
#  17  A4-rank     22060 non-null  object
#  18  A4-level    28325 non-null  float64
#  19  B1-weapon   28340 non-null  object
#  20  B1-rank     22068 non-null  object
#  21  B1-level    28340 non-null  int64
#  22  B2-weapon   28340 non-null  object
#  23  B2-rank     22068 non-null  object
#  24  B2-level    28340 non-null  float64
#  25  B3-weapon   28339 non-null  object
#  26  B3-rank     22067 non-null  object
#  27  B3-level    28339 non-null  float64
#  28  B4-weapon   28310 non-null  object
#  29  B4-rank     22043 non-null  object
#  30  B4-level    28310 non-null  float64
# dtypes: float64(6), int64(3), object(22)
# memory usage: 6.7+ MB

# %%
train.head()
# Out:
#    id                     period game-ver lobby-mode     lobby      mode  \
# 0   1  2019-10-15T20:00:00+00:00    5.0.1    regular  standard  nawabari
# 1   2  2019-12-14T04:00:00+00:00    5.0.1    regular  standard  nawabari
# 2   3  2019-12-25T14:00:00+00:00    5.0.1      gachi  standard      hoko
# 3   4  2019-11-11T14:00:00+00:00    5.0.1    regular  standard  nawabari
# 4   5  2019-12-14T06:00:00+00:00    5.0.1      gachi  standard      hoko
#
#      stage            A1-weapon A1-rank  A1-level           A2-weapon A2-rank  \
# 0  sumeshi      sshooter_becchu     NaN       139     soytuber_custom     NaN
# 1  arowana  parashelter_sorella     NaN       198          jetsweeper     NaN
# 2      ama               nzap89      a-       114    quadhopper_black       a
# 3   engawa          bamboo14mk1     NaN       336  splatroller_becchu     NaN
# 4  chozame               bold_7       x       299          hissen_hue       x
#
#    A2-level            A3-weapon A3-rank  A3-level     A4-weapon A4-rank  \
# 0     118.0            pablo_hue     NaN      13.0       hokusai     NaN
# 1      77.0  campingshelter_camo     NaN     198.0        nzap85     NaN
# 2      68.0         prime_becchu       a     225.0    jetsweeper       a
# 3     131.0         dynamo_tesla     NaN     189.0  prime_becchu     NaN
# 4      97.0          h3reelgun_d       x      96.0   splatroller       x
#
#    A4-level            B1-weapon B1-rank  B1-level       B2-weapon B2-rank  \
# 0      10.0               bold_7     NaN        28  hokusai_becchu     NaN
# 1     123.0               momiji     NaN        83     squiclean_b     NaN
# 2     107.0               bold_7      a-        50          nzap85      a+
# 3      41.0  splatcharger_becchu     NaN       273         liter4k     NaN
# 4     136.0                 furo       x       101    sputtery_hue       x
#
#    B2-level            B3-weapon B3-rank  B3-level           B4-weapon  \
# 0      26.0  herocharger_replica     NaN      68.0           sharp_neo
# 1     118.0       campingshelter     NaN     168.0      sputtery_clear
# 2     163.0         prime_becchu      a-     160.0  dualsweeper_custom
# 3     189.0        promodeler_mg     NaN     194.0   hotblaster_custom
# 4      45.0   bucketslosher_soda       x     246.0              wakaba
#
#   B4-rank  B4-level  y
# 0     NaN      31.0  1
# 1     NaN     151.0  0
# 2       a     126.0  0
# 3     NaN     391.0  0
# 4       x     160.0  1

# %%
test.head()
# Out:
#    id                     period game-ver lobby-mode     lobby    mode  \
# 0   1  2019-12-17T12:00:00+00:00    5.0.1      gachi  standard    area
# 1   2  2019-11-25T16:00:00+00:00    5.0.1      gachi  standard   asari
# 2   3  2019-10-22T08:00:00+00:00    5.0.1      gachi  standard    area
# 3   4  2019-12-30T04:00:00+00:00    5.0.1      gachi  standard   asari
# 4   5  2019-10-15T16:00:00+00:00    5.0.1      gachi  standard  yagura
#
#        stage      A1-weapon A1-rank  A1-level             A2-weapon A2-rank  \
# 0   hakofugu  prime_collabo       x       174   herospinner_replica       x
# 1    anchovy   prime_becchu      s+       363                nzap89      s+
# 2  mutsugoro      furo_deco       s       116                  bold       s
# 3      devon   prime_becchu      s+       192  splatspinner_collabo      s+
# 4    anchovy    l3reelgun_d       x       267          rapid_becchu       x
#
#    A2-level           A3-weapon A3-rank  A3-level           A4-weapon A4-rank  \
# 0     130.0              nzap89       x     127.0         nova_becchu       x
# 1      59.0       dynamo_becchu      s+      36.0        rapid_becchu      s+
# 2     125.0              nzap85       s     124.0              wakaba       s
# 3     115.0               pablo      s+     171.0  dualsweeper_custom      s+
# 4     223.0  heroroller_replica       x     240.0        hydra_custom       x
#
#    A4-level    B1-weapon B1-rank  B1-level           B2-weapon B2-rank  \
# 0     233.0         furo       x       160          nautilus47       x
# 1     225.0         furo      s+       326  dualsweeper_custom      s+
# 2     181.0  splatroller       s        76              momiji       s
# 3     170.0       momiji      s+        90    quadhopper_black      s+
# 4     190.0       nzap83       x       259     sshooter_becchu       x
#
#    B2-level     B3-weapon B3-rank  B3-level            B4-weapon B4-rank  \
# 0     151.0   l3reelgun_d       x     213.0               nzap89       x
# 1     289.0  prime_becchu      s+     147.0          splatroller      s+
# 2     232.0        nzap83       s     183.0        promodeler_pg       s
# 3     119.0      soytuber      s+     172.0                prime      s+
# 4     198.0    splatscope       x      50.0  screwslosher_becchu       x
#
#    B4-level
# 0     306.0
# 1     156.0
# 2     105.0
# 3      70.0
# 4     287.0

# %%
train.isnull().sum()
# Out:
# id                0
# period            0
# game-ver          0
# lobby-mode        0
# lobby             0
# mode              0
# stage             0
# A1-weapon         0
# A1-rank       14444
# A1-level          0
# A2-weapon         0
# A2-rank       14444
# A2-level          0
# A3-weapon         0
# A3-rank       14444
# A3-level          0
# A4-weapon        51
# A4-rank       14487
# A4-level         51
# B1-weapon         0
# B1-rank       14444
# B1-level          0
# B2-weapon         0
# B2-rank       14444
# B2-level          0
# B3-weapon         1
# B3-rank       14444
# B3-level          1
# B4-weapon        67
# B4-rank       14501
# B4-level         67
# y                 0
# dtype: int64

# %%
# trainとtestを縦に連結
df_full = pd.concat([train, test], axis=0, sort=False)
print(df_full.shape) # df_fullの行数と列数を確認
df_full.describe() # df_fullの要約統計量
# Out:
# (94465, 32)
#                  id      A1-level      A2-level      A3-level      A4-level  \
# count  94465.000000  94465.000000  94465.000000  94465.000000  94399.000000
# mean   27395.150003    208.713979    155.143217    153.007230    155.815432
# std    18710.953092    118.847644     96.096398     95.431617     95.463791
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%    11809.000000    120.000000     82.000000     80.000000     84.000000
# 50%    23617.000000    188.000000    139.000000    136.000000    139.000000
# 75%    42509.000000    277.000000    208.000000    205.000000    208.000000
# max    66125.000000    585.000000    913.000000    920.000000    933.000000
#
#            B1-level      B2-level      B3-level      B4-level             y
# count  94465.000000  94465.000000  94463.000000  94368.000000  66125.000000
# mean     156.597502    152.766972    153.118957    157.186016      0.524703
# std       97.310423     95.381686     94.884661     95.395996      0.499393
# min        1.000000      1.000000      1.000000      1.000000      0.000000
# 25%       83.000000     80.000000     81.000000     85.000000      0.000000
# 50%      139.000000    136.000000    137.000000    141.000000      1.000000
# 75%      210.000000    205.000000    205.000000    210.000000      1.000000
# max      920.000000    931.000000    933.000000    936.000000      1.000000

# %%
df_full.describe(include = 'O')
# Out:
#                            period game-ver lobby-mode     lobby   mode  stage  \
# count                       94465    94465      94465     94465  94465  94465
# unique                       1051        1          2         1      5     23
# top     2019-10-12T12:00:00+00:00    5.0.1      gachi  standard   area    ama
# freq                          351    94465      73749     94465  21123   5311
#
#            A1-weapon A1-rank A2-weapon A2-rank     A3-weapon A3-rank  \
# count          94465   73749     94465   73749         94465   73749
# unique           139      12       139      12           139      12
# top     prime_becchu       x    wakaba       x  prime_becchu       x
# freq            9416   35319      4064   35319          3870   35319
#
#           A4-weapon A4-rank B1-weapon B1-rank     B2-weapon B2-rank  \
# count         94399   73698     94465   73749         94465   73749
# unique          139      12       139      12           139      12
# top     splatroller       x    wakaba       x  prime_becchu       x
# freq           4716   35291      4215   35319          4194   35319
#
#            B3-weapon B3-rank    B4-weapon B4-rank
# count          94463   73748        94368   73667
# unique           139      12          139      12
# top     prime_becchu       x  splatroller       x
# freq            4464   35319         4802   35278

# %%
# 不要な列の削除
train.drop(['game-ver','lobby'], axis=1, inplace=True)
test.drop(['game-ver','lobby'], axis=1, inplace=True)

# %%
# coding:utf-8

#Pandasをインポート
import pandas as pd
import json
from pandas.io.json import json_normalize

#変換したいJSONファイルを読み込む
df = pd.read_json('stage_info.json')
print(df)

# read_jsonした結果だとネストしたjsonを展開できないのでnormalizeで展開させる
df_json = json_normalize(df['data'])
df_json.to_csv("stage_info.csv", encoding='utf-8')
stage_info = pd.read_csv('stage_info.csv')
# Out:
#                                                  data
# 0   {'key': 'battera', 'splatnet': 0, 'name': {'de...
# 1   {'key': 'fujitsubo', 'splatnet': 1, 'name': {'...
# 2   {'key': 'gangaze', 'splatnet': 2, 'name': {'de...
# 3   {'key': 'kombu', 'splatnet': 5, 'name': {'de_D...
# 4   {'key': 'ama', 'splatnet': 4, 'name': {'de_DE'...
# 5   {'key': 'chozame', 'splatnet': 3, 'name': {'de...
# 6   {'key': 'hokke', 'splatnet': 7, 'name': {'de_D...
# 7   {'key': 'tachiuo', 'splatnet': 8, 'name': {'de...
# 8   {'key': 'mystery', 'splatnet': 9999, 'name': {...
# 9   {'key': 'manta', 'splatnet': 6, 'name': {'de_D...
# 10  {'key': 'mozuku', 'splatnet': 10, 'name': {'de...
# 11  {'key': 'engawa', 'splatnet': 9, 'name': {'de_...
# 12  {'key': 'bbass', 'splatnet': 11, 'name': {'de_...
# 13  {'key': 'zatou', 'splatnet': 13, 'name': {'de_...
# 14  {'key': 'arowana', 'splatnet': 15, 'name': {'d...
# 15  {'key': 'hakofugu', 'splatnet': 14, 'name': {'...
# 16  {'key': 'devon', 'splatnet': 12, 'name': {'de_...
# 17  {'key': 'ajifry', 'splatnet': 18, 'name': {'de...
# 18  {'key': 'shottsuru', 'splatnet': 17, 'name': {...
# 19  {'key': 'mongara', 'splatnet': 16, 'name': {'d...
# 20  {'key': 'sumeshi', 'splatnet': 20, 'name': {'d...
# 21  {'key': 'otoro', 'splatnet': 19, 'name': {'de_...
# 22  {'key': 'anchovy', 'splatnet': 21, 'name': {'d...
# 23  {'key': 'mutsugoro', 'splatnet': 22, 'name': {...
# 24  {'key': 'mystery_01', 'splatnet': 101, 'name':...
# 25  {'key': 'mystery_02', 'splatnet': 102, 'name':...
# 26  {'key': 'mystery_03', 'splatnet': 103, 'name':...
# 27  {'key': 'mystery_04', 'splatnet': 100, 'name':...
# 28  {'key': 'mystery_05', 'splatnet': 107, 'name':...
# 29  {'key': 'mystery_06', 'splatnet': 106, 'name':...
# 30  {'key': 'mystery_07', 'splatnet': 105, 'name':...
# 31  {'key': 'mystery_08', 'splatnet': 110, 'name':...
# 32  {'key': 'mystery_09', 'splatnet': 108, 'name':...
# 33  {'key': 'mystery_10', 'splatnet': 109, 'name':...
# 34  {'key': 'mystery_11', 'splatnet': 111, 'name':...
# 35  {'key': 'mystery_12', 'splatnet': 113, 'name':...
# 36  {'key': 'mystery_13', 'splatnet': 112, 'name':...
# 37  {'key': 'mystery_14', 'splatnet': 114, 'name':...
# 38  {'key': 'mystery_15', 'splatnet': 115, 'name':...
# 39  {'key': 'mystery_16', 'splatnet': 116, 'name':...
# 40  {'key': 'mystery_17', 'splatnet': 117, 'name':...
# 41  {'key': 'mystery_18', 'splatnet': 118, 'name':...
# 42  {'key': 'mystery_19', 'splatnet': 119, 'name':...
# 43  {'key': 'mystery_20', 'splatnet': 120, 'name':...
# 44  {'key': 'mystery_21', 'splatnet': 121, 'name':...
# 45  {'key': 'mystery_22', 'splatnet': 122, 'name':...
# 46  {'key': 'mystery_23', 'splatnet': 123, 'name':...
# 47  {'key': 'mystery_24', 'splatnet': 124, 'name':...
# <ipython-input-318-234f01f7dab2>:13: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_json = json_normalize(df['data'])

# %%
stage_info.head()
# Out:
#    Unnamed: 0        key  splatnet    area         name.de_DE  \
# 0           0    battera         0  2450.0    Korallenviertel
# 1           1  fujitsubo         1  1957.0      Molluskelbude
# 2           2    gangaze         2  2140.0  Seeigel-Rockbühne
# 3           3      kombu         5  2259.0    Buckelwal-Piste
# 4           4        ama         4  2465.0  Perlmutt-Akademie
#
#             name.en_GB           name.en_US          name.es_ES  \
# 0             The Reef             The Reef      Barrio Congrio
# 1  Musselforge Fitness  Musselforge Fitness   Gimnasio Mejillón
# 2   Starfish Mainstage   Starfish Mainstage     Auditorio Erizo
# 3  Humpback Pump Track  Humpback Pump Track         Tiburódromo
# 4  Inkblot Art Academy  Inkblot Art Academy  Instituto Coralino
#
#            name.es_MX          name.fr_CA           name.fr_FR  \
# 0      Barrio Congrio       Allées salées        Allées salées
# 1   Gimnasio Mejillón     Gymnase Ancrage      Gymnase Ancrage
# 2     Auditorio Erizo        Scène Sirène         Scène Sirène
# 3         Tiburódromo       Piste Méroule        Piste Méroule
# 4  Instituto Coralino  Institut Calm'arts  Institut Calam'arts
#
#               name.it_IT   name.ja_JP       name.nl_NL          name.ru_RU  \
# 0         Rione Storione    バッテラストリート      Sushistraat                 Риф
# 1   Centro polpisportivo  フジツボスポーツクラブ   Vinvis Fitness  Спортзал «Кревед!»
# 2         Palco Plancton    ガンガゼ野外音楽堂  Zeesterrenstage      КЗ «Иглокожий»
# 3  Tintodromo Montecarpa      コンブトラック   Lekkerbektrack   Велозал «9-й вал»
# 4     Campus Hippocampus       海女美術大学     Koraalcampus   Академия «Лепота»
#
#   name.zh_CN name.zh_TW   short_name.de_DE short_name.en_GB short_name.en_US  \
# 0        寿司街        壽司街    Korallenviertel             Reef             Reef
# 1      藤壶健身房      藤壺健身房      Molluskelbude          Fitness          Fitness
# 2    海胆开放音乐台    海膽開放音樂臺  Seeigel-Rockbühne        Mainstage        Mainstage
# 3       昆布赛道       昆布賽道    Buckelwal-Piste            Track            Track
# 4     海女美术大学     海女美術大學  Perlmutt-Akademie          Academy          Academy
#
#      short_name.es_ES    short_name.es_MX    short_name.fr_CA  \
# 0      Barrio Congrio      Barrio Congrio       Allées salées
# 1   Gimnasio Mejillón   Gimnasio Mejillón     Gymnase Ancrage
# 2     Auditorio Erizo     Auditorio Erizo        Scène Sirène
# 3         Tiburódromo         Tiburódromo       Piste Méroule
# 4  Instituto Coralino  Instituto Coralino  Institut Calm'arts
#
#       short_name.fr_FR       short_name.it_IT short_name.ja_JP  \
# 0        Allées salées         Rione Storione             バッテラ
# 1      Gymnase Ancrage   Centro polpisportivo             フジツボ
# 2         Scène Sirène         Palco Plancton             ガンガゼ
# 3        Piste Méroule  Tintodromo Montecarpa              コンブ
# 4  Institut Calam'arts     Campus Hippocampus              アマビ
#
#   short_name.nl_NL    short_name.ru_RU short_name.zh_CN short_name.zh_TW  \
# 0      Sushistraat                 Риф              寿司街              壽司街
# 1   Vinvis Fitness  Спортзал «Кревед!»              健身房              健身房
# 2  Zeesterrenstage      КЗ «Иглокожий»              音乐台              音樂臺
# 3   Lekkerbektrack   Велозал «9-й вал»               赛道               賽道
# 4     Koraalcampus   Академия «Лепота»               大学               大學
#
#    release_at.time         release_at.iso8601
# 0       1490382000  2017-03-24T19:00:00+00:00
# 1       1490382000  2017-03-24T19:00:00+00:00
# 2       1500105600  2017-07-15T08:00:00+00:00
# 3       1500105600  2017-07-15T08:00:00+00:00
# 4       1500105600  2017-07-15T08:00:00+00:00

# %%
weapon_info = pd.read_csv('statink-weapon2.csv')

# %%
weapon_info.head()
# Out:
#   category1 category2            key     subweapon              special  \
# 0   shooter   shooter          52gal   pointsensor               sphere
# 1   shooter   shooter     52gal_deco   curlingbomb              presser
# 2   shooter   shooter          96gal     sprinkler                armor
# 3   shooter   shooter     96gal_deco  splashshield             chakuchi
# 4   shooter   shooter  promodeler_mg    kyubanbomb  curlingbomb_pitcher
#
#       mainweapon         reskin  splatnet          [de-DE]       [en-GB]  \
# 0          52gal          52gal        50       .52 Gallon       .52 Gal
# 1          52gal     52gal_deco        51  .52 Gallon Deko  .52 Gal Deco
# 2          96gal          96gal        80       .96 Gallon       .96 Gal
# 3          96gal     96gal_deco        81  .96 Gallon Deko  .96 Gal Deco
# 4  promodeler_mg  promodeler_mg        30      Airbrush MG  Aerospray MG
#
#         [en-US]              [es-ES]                [es-MX]  \
# 0       .52 Gal     Salpicadora 2000       Salpicadora 2000
# 1  .52 Gal Deco  Salpicadora 2000 DX  Salpicadora 2000 chic
# 2       .96 Gal     Salpicadora 3000       Salpicadora 3000
# 3  .96 Gal Deco  Salpicadora 3000 DX  Salpicadora 3000 chic
# 4  Aerospray MG        Aerógrafo pro           Aerógrafo GP
#
#              [fr-CA]            [fr-FR]          [it-IT]   [ja-JP]  \
# 0       Calibre 2000       Calibre 2000     Calibro 2000    .52ガロン
# 1  Calibre 2000 chic  Calibre 2000 chic  Calibro 2000 DX  .52ガロンデコ
# 2       Calibre 3000       Calibre 3000     Calibro 3000    .96ガロン
# 3  Calibre 3000 chic  Calibre 3000 chic  Calibro 3000 DX  .96ガロンデコ
# 4      Pouche-pouche            Aérogun        Aerografo  プロモデラーMG
#
#             [nl-NL]              [ru-RU]       [zh-CN]       [zh-TW]
# 0       .52 Kaliter         Струевик .52       点52口径重枪       點52口徑重槍
# 1  .52 Kaliter Deco  Струевик .52 «Деко»  点52口径重枪 Deco  點52口徑重槍 Deco
# 2       .96 Kaliter         Струевик .96       点96口径重枪       點96口徑重槍
# 3  .96 Kaliter Deco  Струевик .96 «Деко»  点96口径重枪 Deco  點96口徑重槍 Deco
# 4     Kladderwerper            Аэроспрей          银色喷枪          銀色噴槍

# %%
# 一旦periodとstageを消してみる
train.drop(['period'], axis=1, inplace=True)
test.drop(['period'], axis=1, inplace=True)

# %%
# 武器の辞書を作成
dic = weapon_info.set_index('key')['category2'].to_dict()
dic
# Out:
# {'52gal': 'shooter',
#  '52gal_deco': 'shooter',
#  '96gal': 'shooter',
#  '96gal_deco': 'shooter',
#  'promodeler_mg': 'shooter',
#  'promodeler_pg': 'shooter',
#  'promodeler_rg': 'shooter',
#  'jetsweeper_custom': 'shooter',
#  'momiji': 'shooter',
#  'bottlegeyser_foil': 'shooter',
#  'prime_collabo': 'shooter',
#  'heroshooter_replica': 'shooter',
#  'jetsweeper': 'shooter',
#  '52gal_becchu': 'shooter',
#  'sshooter_becchu': 'shooter',
#  'ochiba': 'shooter',
#  'prime_becchu': 'shooter',
#  'sharp_neo': 'shooter',
#  'bold_neo': 'shooter',
#  'nzap83': 'shooter',
#  'nzap85': 'shooter',
#  'nzap89': 'shooter',
#  'octoshooter_replica': 'shooter',
#  'sharp': 'shooter',
#  'sshooter': 'shooter',
#  'wakaba': 'shooter',
#  'prime': 'shooter',
#  'bold': 'shooter',
#  'bold_7': 'shooter',
#  'bottlegeyser': 'shooter',
#  'sshooter_collabo': 'shooter',
#  'hotblaster': 'blaster',
#  'clashblaster': 'blaster',
#  'clashblaster_neo': 'blaster',
#  'hotblaster_custom': 'blaster',
#  'longblaster_custom': 'blaster',
#  'longblaster_necro': 'blaster',
#  'heroblaster_replica': 'blaster',
#  'nova_becchu': 'blaster',
#  'rapid_becchu': 'blaster',
#  'nova': 'blaster',
#  'nova_neo': 'blaster',
#  'longblaster': 'blaster',
#  'rapid': 'blaster',
#  'rapid_deco': 'blaster',
#  'rapid_elite': 'blaster',
#  'rapid_elite_deco': 'blaster',
#  'sputtery_clear': 'maneuver',
#  'dualsweeper_custom': 'maneuver',
#  'sputtery': 'maneuver',
#  'sputtery_hue': 'maneuver',
#  'quadhopper_black': 'maneuver',
#  'dualsweeper': 'maneuver',
#  'maneuver_collabo': 'maneuver',
#  'kelvin525': 'maneuver',
#  'kelvin525_deco': 'maneuver',
#  'heromaneuver_replica': 'maneuver',
#  'kelvin525_becchu': 'maneuver',
#  'maneuver_becchu': 'maneuver',
#  'quadhopper_white': 'maneuver',
#  'maneuver': 'maneuver',
#  'h3reelgun_cherry': 'reelgun',
#  'h3reelgun': 'reelgun',
#  'h3reelgun_d': 'reelgun',
#  'l3reelgun_becchu': 'reelgun',
#  'l3reelgun': 'reelgun',
#  'l3reelgun_d': 'reelgun',
#  'carbon': 'roller',
#  'carbon_deco': 'roller',
#  'dynamo': 'roller',
#  'variableroller': 'roller',
#  'variableroller_foil': 'roller',
#  'dynamo_tesla': 'roller',
#  'heroroller_replica': 'roller',
#  'dynamo_becchu': 'roller',
#  'splatroller_becchu': 'roller',
#  'splatroller_collabo': 'roller',
#  'splatroller': 'roller',
#  'herobrush_replica': 'brush',
#  'pablo': 'brush',
#  'pablo_hue': 'brush',
#  'hokusai_becchu': 'brush',
#  'hokusai': 'brush',
#  'hokusai_hue': 'brush',
#  'pablo_permanent': 'brush',
#  'bamboo14mk1': 'charger',
#  'bamboo14mk2': 'charger',
#  'bamboo14mk3': 'charger',
#  'squiclean_a': 'charger',
#  'liter4k_custom': 'charger',
#  'liter4k_scope_custom': 'charger',
#  'soytuber_custom': 'charger',
#  'liter4k': 'charger',
#  'liter4k_scope': 'charger',
#  'splatcharger_collabo': 'charger',
#  'splatscope_collabo': 'charger',
#  'squiclean_g': 'charger',
#  'soytuber': 'charger',
#  'herocharger_replica': 'charger',
#  'splatcharger_becchu': 'charger',
#  'splatscope_becchu': 'charger',
#  'squiclean_b': 'charger',
#  'splatcharger': 'charger',
#  'splatscope': 'charger',
#  'furo': 'slosher',
#  'furo_deco': 'slosher',
#  'explosher_custom': 'slosher',
#  'explosher': 'slosher',
#  'heroslosher_replica': 'slosher',
#  'screwslosher_becchu': 'slosher',
#  'bucketslosher': 'slosher',
#  'bucketslosher_deco': 'slosher',
#  'screwslosher': 'slosher',
#  'screwslosher_neo': 'slosher',
#  'bucketslosher_soda': 'slosher',
#  'hissen': 'slosher',
#  'hissen_hue': 'slosher',
#  'kugelschreiber': 'splatling',
#  'kugelschreiber_hue': 'splatling',
#  'hydra_custom': 'splatling',
#  'barrelspinner': 'splatling',
#  'barrelspinner_deco': 'splatling',
#  'barrelspinner_remix': 'splatling',
#  'herospinner_replica': 'splatling',
#  'hydra': 'splatling',
#  'splatspinner_becchu': 'splatling',
#  'splatspinner': 'splatling',
#  'nautilus47': 'splatling',
#  'nautilus79': 'splatling',
#  'splatspinner_collabo': 'splatling',
#  'heroshelter_replica': 'brella',
#  'spygadget_becchu': 'brella',
#  'parashelter_sorella': 'brella',
#  'parashelter': 'brella',
#  'campingshelter': 'brella',
#  'campingshelter_camo': 'brella',
#  'campingshelter_sorella': 'brella',
#  'spygadget': 'brella',
#  'spygadget_sorella': 'brella'}

# %%
# 武器をカテゴリーに置換
train['A1-weapon'] = train['A1-weapon'].replace(dic)
train['A2-weapon'] = train['A2-weapon'].replace(dic)
train['A3-weapon'] = train['A3-weapon'].replace(dic)
train['A4-weapon'] = train['A4-weapon'].replace(dic)
train['B1-weapon'] = train['B1-weapon'].replace(dic)
train['B2-weapon'] = train['B2-weapon'].replace(dic)
train['B3-weapon'] = train['B3-weapon'].replace(dic)
train['B4-weapon'] = train['B4-weapon'].replace(dic)

# %%
train.head()
# Out:
#    id lobby-mode      mode    stage A1-weapon A1-rank  A1-level A2-weapon  \
# 0   1    regular  nawabari  sumeshi   shooter     NaN       139   charger
# 1   2    regular  nawabari  arowana    brella     NaN       198   shooter
# 2   3      gachi      hoko      ama   shooter      a-       114  maneuver
# 3   4    regular  nawabari   engawa   charger     NaN       336    roller
# 4   5      gachi      hoko  chozame   shooter       x       299   slosher
#
#   A2-rank  A2-level A3-weapon A3-rank  A3-level A4-weapon A4-rank  A4-level  \
# 0     NaN     118.0     brush     NaN      13.0     brush     NaN      10.0
# 1     NaN      77.0    brella     NaN     198.0   shooter     NaN     123.0
# 2       a      68.0   shooter       a     225.0   shooter       a     107.0
# 3     NaN     131.0    roller     NaN     189.0   shooter     NaN      41.0
# 4       x      97.0   reelgun       x      96.0    roller       x     136.0
#
#   B1-weapon B1-rank  B1-level B2-weapon B2-rank  B2-level B3-weapon B3-rank  \
# 0   shooter     NaN        28     brush     NaN      26.0   charger     NaN
# 1   shooter     NaN        83   charger     NaN     118.0    brella     NaN
# 2   shooter      a-        50   shooter      a+     163.0   shooter      a-
# 3   charger     NaN       273   charger     NaN     189.0   shooter     NaN
# 4   slosher       x       101  maneuver       x      45.0   slosher       x
#
#    B3-level B4-weapon B4-rank  B4-level  y
# 0      68.0   shooter     NaN      31.0  1
# 1     168.0  maneuver     NaN     151.0  0
# 2     160.0  maneuver       a     126.0  0
# 3     194.0   blaster     NaN     391.0  0
# 4     246.0   shooter       x     160.0  1

# %%
# A4-level, B3-level, B4-level のNanを０に置換
train['A4-level'].fillna(0, inplace=True)
train['B3-level'].fillna(0, inplace=True)
train['B4-level'].fillna(0, inplace=True)

# %%
# Nanを置換する
train = train.replace(np.nan, '', regex=True)
test = test.replace(np.nan, '', regex=True)

# %%
# Label Encording
le = preprocessing.LabelEncoder()
for column in ['stage','lobby-mode','mode','A1-rank','A2-rank','A3-rank','A4-rank','B1-rank','B2-rank','B3-rank','B4-rank','A1-weapon','A2-weapon','A3-weapon','A4-weapon','B1-weapon','B2-weapon','B3-weapon','B4-weapon']:
#     print(titanic[column].shape)
    le = preprocessing.LabelEncoder()
    le.fit(train[column])
    train[column] = le.transform(train[column])

# %%
# One Hot Encoding
# train = pd.get_dummies(train, columns=['lobby-mode','A1-rank','A2-rank','A3-rank','A4-rank','B1-rank','B2-rank','B3-rank','B4-rank','A1-weapon','A2-weapon','A3-weapon','A4-weapon','B1-weapon','B2-weapon','B3-weapon','B4-weapon'])
# test = pd.get_dummies(test, columns=['lobby-mode','A1-rank','A2-rank','A3-rank','A4-rank','B1-rank','B2-rank','B3-rank','B4-rank','A1-weapon','A2-weapon','A3-weapon','A4-weapon','B1-weapon','B2-weapon','B3-weapon','B4-weapon'])

# %%
X_train = train.drop(['y'], axis=1) # X_trainはtrainのSurvived列以外
y_train = train['y'] # y_trainはtrainのSurvived列

# %%
train.head()
# Out:
#    id  lobby-mode  mode  stage  A1-weapon  A1-rank  A1-level  A2-weapon  \
# 0   1           1     3     20          7        0       139          3
# 1   2           1     3      3          1        0       198          7
# 2   3           0     2      1          7        3       114          4
# 3   4           1     3      8          3        0       336          6
# 4   5           0     2      6          7       12       299          8
#
#    A2-rank  A2-level  A3-weapon  A3-rank  A3-level  A4-weapon  A4-rank  \
# 0        0     118.0          2        0      13.0          3        0
# 1        0      77.0          1        0     198.0          8        0
# 2        1      68.0          7        1     225.0          8        1
# 3        0     131.0          6        0     189.0          8        0
# 4       12      97.0          5       12      96.0          7       12
#
#    A4-level  B1-weapon  B1-rank  B1-level  B2-weapon  B2-rank  B2-level  \
# 0      10.0          7        0        28          2        0      26.0
# 1     123.0          7        0        83          3        0     118.0
# 2     107.0          7        3        50          7        2     163.0
# 3      41.0          3        0       273          3        0     189.0
# 4     136.0          8       12       101          4       12      45.0
#
#    B3-weapon  B3-rank  B3-level  B4-weapon  B4-rank  B4-level  y
# 0          4        0      68.0          8        0      31.0  1
# 1          2        0     168.0          5        0     151.0  0
# 2          8        3     160.0          5        1     126.0  0
# 3          8        0     194.0          1        0     391.0  0
# 4          9       12     246.0          8       12     160.0  1

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# X_trainとy_trainをtrainとvalidに分割
train_x, valid_x, train_y, valid_y = train_test_split(X_train, y_train,
test_size=0.33, random_state=0)
# lgb.Datasetでtrainとvalidを作っておく
lgb_train = lgb.Dataset(train_x, train_y)
lgb_eval = lgb.Dataset(valid_x, valid_y)
# パラメータを定義
lgbm_params = {'objective': 'binary'}
# lgb.trainで学習
evals_result = {}
gbm = lgb.train(params=lgbm_params,
    train_set=lgb_train,
    valid_sets=[lgb_train, lgb_eval],
    early_stopping_rounds=50,
    evals_result=evals_result,
    verbose_eval=10);
# Out:
# Training until validation scores don't improve for 50 rounds
# [10]	training's binary_logloss: 0.682093	valid_1's binary_logloss: 0.688031
# [20]	training's binary_logloss: 0.675145	valid_1's binary_logloss: 0.686181
# [30]	training's binary_logloss: 0.669419	valid_1's binary_logloss: 0.685814
# [40]	training's binary_logloss: 0.664241	valid_1's binary_logloss: 0.68568
# [50]	training's binary_logloss: 0.659266	valid_1's binary_logloss: 0.685647
# [60]	training's binary_logloss: 0.654516	valid_1's binary_logloss: 0.685703
# [70]	training's binary_logloss: 0.650033	valid_1's binary_logloss: 0.685768
# [80]	training's binary_logloss: 0.6456	valid_1's binary_logloss: 0.685914
# [90]	training's binary_logloss: 0.641288	valid_1's binary_logloss: 0.686174
# Early stopping, best iteration is:
# [43]	training's binary_logloss: 0.662718	valid_1's binary_logloss: 0.685496

# %%
oof = (gbm.predict(valid_x) > 0.5).astype(int)
print('score', round(accuracy_score(valid_y, oof)*100, 2))
# Out:
# score 53.67

# %%
train.info
# Out:
# <bound method DataFrame.info of           id  lobby-mode  mode  stage  A1-weapon  A1-rank  A1-level  \
# 0          1           1     3     20          7        0       139
# 1          2           1     3      3          1        0       198
# 2          3           0     2      1          7        3       114
# 3          4           1     3      8          3        0       336
# 4          5           0     2      6          7       12       299
# ...      ...         ...   ...    ...        ...      ...       ...
# 66120  66121           0     0      7          2        1        66
# 66121  66122           0     1     18          2       11       204
# 66122  66123           0     2      5          7        2       116
# 66123  66124           0     0      9          6       11       210
# 66124  66125           0     1     20          6       10       132
#
#        A2-weapon  A2-rank  A2-level  A3-weapon  A3-rank  A3-level  A4-weapon  \
# 0              3        0     118.0          2        0      13.0          3
# 1              7        0      77.0          1        0     198.0          8
# 2              4        1      68.0          7        1     225.0          8
# 3              6        0     131.0          6        0     189.0          8
# 4              8       12      97.0          5       12      96.0          7
# ...          ...      ...       ...        ...      ...       ...        ...
# 66120          3        1     113.0          7        2     114.0          8
# 66121          7       11      96.0          7       11     112.0          8
# 66122          7        1      86.0          8        3      19.0          8
# 66123          7       11      96.0          4       11     126.0          8
# 66124          7       10     324.0          9       10     117.0          8
#
#        A4-rank  A4-level  B1-weapon  B1-rank  B1-level  B2-weapon  B2-rank  \
# 0            0      10.0          7        0        28          2        0
# 1            0     123.0          7        0        83          3        0
# 2            1     107.0          7        3        50          7        2
# 3            0      41.0          3        0       273          3        0
# 4           12     136.0          8       12       101          4       12
# ...        ...       ...        ...      ...       ...        ...      ...
# 66120        2     123.0          7        2       509          7        2
# 66121       11      44.0          8       11       163          7       11
# 66122        2      69.0          6        2       205          7        2
# 66123       11     453.0          7       11        91          6       11
# 66124       10     151.0          7       10        55          7       10
#
#        B2-level  B3-weapon  B3-rank  B3-level  B4-weapon  B4-rank  B4-level  y
# 0          26.0          4        0      68.0          8        0      31.0  1
# 1         118.0          2        0     168.0          5        0     151.0  0
# 2         163.0          8        3     160.0          5        1     126.0  0
# 3         189.0          8        0     194.0          1        0     391.0  0
# 4          45.0          9       12     246.0          8       12     160.0  1
# ...         ...        ...      ...       ...        ...      ...       ... ..
# 66120     272.0          4        1      38.0          8        2     283.0  1
# 66121     167.0          3       11     188.0          8       11     170.0  1
# 66122      70.0          8        2     191.0          9        2     139.0  1
# 66123     395.0          1       11     223.0          8       11     194.0  0
# 66124     124.0          6       10     103.0          3       10      35.0  0
#
# [66125 rows x 29 columns]>

# %%
train['A1-rank']
# Out:
# 0        NaN
# 1        NaN
# 2         a-
# 3        NaN
# 4          x
#         ...
# 66120      a
# 66121     s+
# 66122     a+
# 66123     s+
# 66124      s
# Name: A1-rank, Length: 66125, dtype: object
